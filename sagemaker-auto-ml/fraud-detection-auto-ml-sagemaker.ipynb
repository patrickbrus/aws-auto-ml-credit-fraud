# %% [markdown]
# # Sagemaker AutoML Fraud Detection
# This notebook contains the code to start a sagemaker automl job for the fraud detection Kaggle challenge.
#
# The code is partly taken and inspired by [this](https://gitlab.com/juliensimon/aim307/-/blob/master/aim307.ipynb) aws example notebook.

# %%
# %%sh
# pip install --upgrade pip
# pip -q install sagemaker awscli boto3 --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (22.3.1)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-23.0.1

# %%
import numpy as np 
import pandas as pd
import boto3
import sagemaker
import os, sys
import time

print (sagemaker.__version__)
# Out:
# 2.145.0

# %%
sess   = sagemaker.Session()
bucket = sess.default_bucket()                     
region = boto3.Session().region_name
prefix = 'sagemaker/fraud-detection-auto-ml'
# Role when working on a notebook instance
role = sagemaker.get_execution_role()

# %%
sm = boto3.Session().client(service_name='sagemaker',region_name=region)
sm_rt = boto3.Session().client('runtime.sagemaker', region_name=region)

# %% [markdown]
# ## Read Data from S3

# %%
bucket_data = 'patrick-fraud-detection-ml-kaggle'
filename = 'creditcard.csv'

s3 = boto3.client('s3') 

obj = s3.get_object(Bucket=bucket_data, Key=filename) 
# get object and file (key) from bucket

df = pd.read_csv(obj['Body']) # 'Body' is a key word

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# check number of samples
num_samples, num_features = df.shape

print(f"There are {num_samples} samples with {num_features} features each.")
# Out:
# There are 284807 samples with 31 features each.

# %%
# check data imbalance on target
count_neg_class = np.sum(df["Class"] == 0)
count_pos_class = np.sum(df["Class"] == 1)

print(f"There are {count_neg_class} negative samples ({np.round(100 * count_neg_class / num_samples, 2)} % of total data).")
print(f"There are {count_pos_class} positive samples ({np.round(100 * count_pos_class / num_samples, 2)} % of total data).")
# Out:
# There are 284315 negative samples (99.83 % of total data).
# There are 492 positive samples (0.17 % of total data).

# %% [markdown]
# ## Splitting the dataset
#
# Split dataset into train and test. The train set is again split during AutoML job into train and validation.

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, test_size=0.2)

# Save to CSV files and upload to S3
train_file = "automl-train.csv"
train_data.to_csv(train_file, index=False, header=True, sep=',') # Need to keep column names
train_data_s3_path = sess.upload_data(path=train_file, key_prefix=prefix + "/train")
print("Train data uploaded to: " + train_data_s3_path)

test_file = "automl-test.csv"
test_file_no_target = "automl-test-no-target.csv"
test_data_no_target = test_data.drop(columns=["Class"])
test_data.to_csv(test_file, index=False, header=False, sep=',')
test_data_no_target.to_csv(test_file_no_target, index=False, header=False, sep=',')
test_data_s3_path = sess.upload_data(path=test_file, key_prefix=prefix + "/test")
test_data_s3_path_no_target = sess.upload_data(path=test_file_no_target, key_prefix=prefix + "/test")
print("Test data uploaded to: " + test_data_s3_path)
print("Test data no target uploaded to: " + test_data_s3_path_no_target)
# Out:
# Train data uploaded to: s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/train/automl-train.csv
# Test data uploaded to: s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/test/automl-test.csv
# Test data no target uploaded to: s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/test/automl-test-no-target.csv

# %% [markdown]
# ## Setting up Sagemaker AutoML Job

# %%
input_data_config = [{
      'DataSource': {
        'S3DataSource': {
          'S3DataType': 'S3Prefix',
          'S3Uri': 's3://{}/{}/input'.format(bucket,prefix)
        }
      },
      'TargetAttributeName': 'Class'  # the column we want to predict
    }
]

output_data_config = { 'S3OutputPath': 's3://{}/{}/output'.format(bucket,prefix) }

# Optional parameters

problem_type = 'BinaryClassification'

job_objective = { 'MetricName': 'F1' }

# %% [markdown]
# ## Launching the Amazon SageMaker AutoPilot job
#
# Let's now launch the job by calling the create_auto_ml_job API.

# %%
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())

auto_ml_job_name = 'fraud-detection-' + timestamp_suffix
print('AutoMLJobName: ' + auto_ml_job_name)

sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      AutoMLJobConfig={"CompletionCriteria": {"MaxCandidates": 20}},
                      AutoMLJobObjective=job_objective,
                      ProblemType=problem_type,
                      RoleArn=role)
# Out:
# AutoMLJobName: fraud-detection-11-04-46-52
# {'AutoMLJobArn': 'arn:aws:sagemaker:eu-central-1:705561729853:automl-job/fraud-detection-11-04-46-52',
#  'ResponseMetadata': {'RequestId': 'e02dc03a-508e-4152-8159-7cf8025776c3',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'e02dc03a-508e-4152-8159-7cf8025776c3',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '101',
#    'date': 'Tue, 11 Apr 2023 04:46:54 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Tracking Progress
# We can now track the progess of the job.

# %%
# %%time
job_run_status = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['AutoMLJobStatus']

print(job_run_status)

while job_run_status not in ('Failed', 'Completed', 'Stopped'):
    describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    job_run_status = describe_response['AutoMLJobStatus']
    
    print (describe_response['AutoMLJobStatus'] + " - " + describe_response['AutoMLJobSecondaryStatus'])
    sleep(60)
# Out:
# InProgress
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# Completed - Completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:10
#
# KeyboardInterrupt:

# %% [markdown]
# ## Fetching the auto-generated notebooks
# Once the 'AnalyzingData' step is complete, SageMaker AutoPilot generates two notebooks:
# 1. Data exploration
# 2. Candidate definition.

# %%
job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_candidate_notebook = job['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
job_data_notebook = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation']

print(job_candidate_notebook)
print(job_data_notebook)
# Out:
# s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/output/fraud-detection-11-04-46-52/sagemaker-automl-candidates/fraud-detection-11-04-46-52-pr-1-7b0617c0121c411b883dc943f7869e/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/output/fraud-detection-11-04-46-52/sagemaker-automl-candidates/fraud-detection-11-04-46-52-pr-1-7b0617c0121c411b883dc943f7869e/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %%
# %%sh -s $job_candidate_notebook $job_data_notebook
# aws s3 cp $1 .
# aws s3 cp $2 .
# Out:
# download: s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/output/fraud-detection-11-04-46-52/sagemaker-automl-candidates/fraud-detection-11-04-46-52-pr-1-7b0617c0121c411b883dc943f7869e/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb to ./SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# download: s3://sagemaker-eu-central-1-705561729853/sagemaker/fraud-detection-auto-ml/output/fraud-detection-11-04-46-52/sagemaker-automl-candidates/fraud-detection-11-04-46-52-pr-1-7b0617c0121c411b883dc943f7869e/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb to ./SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# ## Inspecting the SageMaker Autopilot job with Amazon SageMaker Experiments
# Once the 'ModelTuning' step starts, we can use the SageMaker Experiments SDK to list and view all jobs. Data is stored in a pandas dataframe, which makes it easy to filter it, compare it to other experiments, etc.

# %%
from sagemaker.analytics import ExperimentAnalytics

analytics = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=auto_ml_job_name+'-aws-auto-ml-job'
)

df = analytics.dataframe()
df
# Out:
#                                    TrialComponentName  \
# 0   fraud-detection-11-04-46-52EtgHM-018-83744956-...
# 1   fraud-detection-11-04-46-52EtgHM-016-60c6d19a-...
# 2   fraud-detection-11-04-46-52EtgHM-020-93507b1b-...
# 3   fraud-detection-11-04-46-52EtgHM-013-bc761f4a-...
# 4   fraud-detection-11-04-46-52EtgHM-015-ef5ac858-...
# 5   fraud-detection-11-04-46-52EtgHM-003-fda6791a-...
# 6   fraud-detection-11-04-46-52EtgHM-002-e2cf2bfc-...
# 7   fraud-detection-11-04-46-52EtgHM-001-b993bea5-...
# 8   fraud-detection-11-04-46-52EtgHM-017-234e8ee6-...
# 9   fraud-detection-11-04-46-52EtgHM-019-09a41b6d-...
# 10  fraud-detection-11-04-46-52EtgHM-012-19c6af6a-...
# 11  fraud-detection-11-04-46-52EtgHM-011-218f95f5-...
# 12  fraud-detection-11-04-46-52EtgHM-014-2eb92b33-...
# 13  fraud-detection-11-04-46-52EtgHM-010-e1afb4b5-...
# 14  fraud-detection-11-04-46-52EtgHM-005-8200efaa-...
# 15  fraud-detection-11-04-46-52EtgHM-004-0aeeed95-...
# 16  fraud-detection-11-04-46-52EtgHM-009-f9c2449d-...
# 17  fraud-detection-11-04-46-52EtgHM-008-c5fbd4ef-...
# 18  fraud-detection-11-04-46-52EtgHM-007-526ae705-...
# 19  fraud-detection-11-04-46-52EtgHM-006-59b99a28-...
# 20  fraud-detection-11-04-46-52-dpp1-csv-1-45c7b07...
# 21  fraud-detection-11-04-46-52-dpp4-rpb-1-acce2f8...
# 22  fraud-detection-11-04-46-52-dpp2-rpb-1-ed87b9b...
# 23  fraud-detection-11-04-46-52-dpp6-csv-1-2c66f3e...
# 24  fraud-detection-11-04-46-52-dpp0-csv-1-94ee469...
# 25  fraud-detection-11-04-46-52-dpp5-csv-1-771a624...
# 26  fraud-detection-11-04-46-52-dpp6-1-2abba3e5ec3...
# 27  fraud-detection-11-04-46-52-dpp4-1-5c340f3afb7...
# 28  fraud-detection-11-04-46-52-dpp1-1-2ba109ed5a9...
# 29  fraud-detection-11-04-46-52-dpp2-1-f2044200b18...
# 30  fraud-detection-11-04-46-52-dpp5-1-6233c36102b...
# 31  fraud-detection-11-04-46-52-dpp0-1-e1a1c806b8d...
# 32  fraud-detection-11-04-46-52-db-1-86febe32010e4...
#
#                                           DisplayName  \
# 0   fraud-detection-11-04-46-52EtgHM-018-83744956-...
# 1   fraud-detection-11-04-46-52EtgHM-016-60c6d19a-...
# 2   fraud-detection-11-04-46-52EtgHM-020-93507b1b-...
# 3   fraud-detection-11-04-46-52EtgHM-013-bc761f4a-...
# 4   fraud-detection-11-04-46-52EtgHM-015-ef5ac858-...
# 5   fraud-detection-11-04-46-52EtgHM-003-fda6791a-...
# 6   fraud-detection-11-04-46-52EtgHM-002-e2cf2bfc-...
# 7   fraud-detection-11-04-46-52EtgHM-001-b993bea5-...
# 8   fraud-detection-11-04-46-52EtgHM-017-234e8ee6-...
# 9   fraud-detection-11-04-46-52EtgHM-019-09a41b6d-...
# 10  fraud-detection-11-04-46-52EtgHM-012-19c6af6a-...
# 11  fraud-detection-11-04-46-52EtgHM-011-218f95f5-...
# 12  fraud-detection-11-04-46-52EtgHM-014-2eb92b33-...
# 13  fraud-detection-11-04-46-52EtgHM-010-e1afb4b5-...
# 14  fraud-detection-11-04-46-52EtgHM-005-8200efaa-...
# 15  fraud-detection-11-04-46-52EtgHM-004-0aeeed95-...
# 16  fraud-detection-11-04-46-52EtgHM-009-f9c2449d-...
# 17  fraud-detection-11-04-46-52EtgHM-008-c5fbd4ef-...
# 18  fraud-detection-11-04-46-52EtgHM-007-526ae705-...
# 19  fraud-detection-11-04-46-52EtgHM-006-59b99a28-...
# 20  fraud-detection-11-04-46-52-dpp1-csv-1-45c7b07...
# 21  fraud-detection-11-04-46-52-dpp4-rpb-1-acce2f8...
# 22  fraud-detection-11-04-46-52-dpp2-rpb-1-ed87b9b...
# 23  fraud-detection-11-04-46-52-dpp6-csv-1-2c66f3e...
# 24  fraud-detection-11-04-46-52-dpp0-csv-1-94ee469...
# 25  fraud-detection-11-04-46-52-dpp5-csv-1-771a624...
# 26  fraud-detection-11-04-46-52-dpp6-1-2abba3e5ec3...
# 27  fraud-detection-11-04-46-52-dpp4-1-5c340f3afb7...
# 28  fraud-detection-11-04-46-52-dpp1-1-2ba109ed5a9...
# 29  fraud-detection-11-04-46-52-dpp2-1-f2044200b18...
# 30  fraud-detection-11-04-46-52-dpp5-1-6233c36102b...
# 31  fraud-detection-11-04-46-52-dpp0-1-e1a1c806b8d...
# 32  fraud-detection-11-04-46-52-db-1-86febe32010e4...
#
#                                             SourceArn  \
# 0   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 1   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 2   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 3   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 4   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 5   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 6   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 7   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 8   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 9   arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 10  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 11  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 12  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 13  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 14  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 15  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 16  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 17  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 18  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 19  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 20  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 21  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 22  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 23  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 24  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 25  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 26  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 27  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 28  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 29  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 30  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 31  arn:aws:sagemaker:eu-central-1:705561729853:tr...
# 32  arn:aws:sagemaker:eu-central-1:705561729853:pr...
#
#                                    SageMaker.ImageUri  \
# 0   664544806723.dkr.ecr.eu-central-1.amazonaws.co...
# 1   664544806723.dkr.ecr.eu-central-1.amazonaws.co...
# 2   664544806723.dkr.ecr.eu-central-1.amazonaws.co...
# 3   492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 4   492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 5   492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 6   492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 7   492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 8   664544806723.dkr.ecr.eu-central-1.amazonaws.co...
# 9   492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 10  664544806723.dkr.ecr.eu-central-1.amazonaws.co...
# 11  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 12  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 13  664544806723.dkr.ecr.eu-central-1.amazonaws.co...
# 14  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 15  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 16  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 17  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 18  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 19  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 27  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 28  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 29  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 30  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 31  492215442770.dkr.ecr.eu-central-1.amazonaws.co...
# 32                                                NaN
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                       1.0         ml.m5.12xlarge                      50.0
# 1                       1.0         ml.m5.12xlarge                      50.0
# 2                       1.0         ml.m5.12xlarge                      50.0
# 3                       1.0         ml.m5.12xlarge                      50.0
# 4                       1.0         ml.m5.12xlarge                      50.0
# 5                       1.0         ml.m5.12xlarge                      50.0
# 6                       1.0         ml.m5.12xlarge                      50.0
# 7                       1.0         ml.m5.12xlarge                      50.0
# 8                       1.0         ml.m5.12xlarge                      50.0
# 9                       1.0         ml.m5.12xlarge                      50.0
# 10                      1.0         ml.m5.12xlarge                      50.0
# 11                      1.0         ml.m5.12xlarge                      50.0
# 12                      1.0         ml.m5.12xlarge                      50.0
# 13                      1.0         ml.m5.12xlarge                      50.0
# 14                      1.0         ml.m5.12xlarge                      50.0
# 15                      1.0         ml.m5.12xlarge                      50.0
# 16                      1.0         ml.m5.12xlarge                      50.0
# 17                      1.0         ml.m5.12xlarge                      50.0
# 18                      1.0         ml.m5.12xlarge                      50.0
# 19                      1.0         ml.m5.12xlarge                      50.0
# 20                      1.0          ml.m5.4xlarge                       NaN
# 21                      1.0          ml.m5.4xlarge                       NaN
# 22                      1.0          ml.m5.4xlarge                       NaN
# 23                      1.0          ml.m5.4xlarge                       NaN
# 24                      1.0          ml.m5.4xlarge                       NaN
# 25                      1.0          ml.m5.4xlarge                       NaN
# 26                      1.0         ml.m5.12xlarge                      50.0
# 27                      1.0         ml.m5.12xlarge                      50.0
# 28                      1.0         ml.m5.12xlarge                      50.0
# 29                      1.0         ml.m5.12xlarge                      50.0
# 30                      1.0         ml.m5.12xlarge                      50.0
# 31                      1.0         ml.m5.12xlarge                      50.0
# 32                      1.0          ml.m5.2xlarge                     250.0
#
#     _tuning_objective_metric  \
# 0   validation:binary_f_beta
# 1   validation:binary_f_beta
# 2   validation:binary_f_beta
# 3       validation:f1_binary
# 4       validation:f1_binary
# 5       validation:f1_binary
# 6       validation:f1_binary
# 7       validation:f1_binary
# 8   validation:binary_f_beta
# 9       validation:f1_binary
# 10  validation:binary_f_beta
# 11      validation:f1_binary
# 12      validation:f1_binary
# 13  validation:binary_f_beta
# 14      validation:f1_binary
# 15      validation:f1_binary
# 16      validation:f1_binary
# 17      validation:f1_binary
# 18      validation:f1_binary
# 19      validation:f1_binary
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN
# 31                       NaN
# 32                       NaN
#
#                                           eval_metric  learning_rate  ...  \
# 0                                       binary_f_beta       0.000686  ...
# 1                                          binary_f_1       0.003550  ...
# 2                                       binary_f_beta       0.001518  ...
# 3   accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 4   accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 5   accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 6   accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 7   accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 8                                       binary_f_beta       0.000003  ...
# 9   accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 10                                      binary_f_beta       0.000155  ...
# 11  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 12  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 13                                      binary_f_beta       0.000195  ...
# 14  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 15  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 16  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 17  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 18  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 19  accuracy,f1_binary,auc,balanced_accuracy,preci...            NaN  ...
# 20                                                NaN            NaN  ...
# 21                                                NaN            NaN  ...
# 22                                                NaN            NaN  ...
# 23                                                NaN            NaN  ...
# 24                                                NaN            NaN  ...
# 25                                                NaN            NaN  ...
# 26                                                NaN            NaN  ...
# 27                                                NaN            NaN  ...
# 28                                                NaN            NaN  ...
# 29                                                NaN            NaN  ...
# 30                                                NaN            NaN  ...
# 31                                                NaN            NaN  ...
# 32                                                NaN            NaN  ...
#
#    enable_validation_split  input_channel_mode                     job_name  \
# 0                      NaN                 NaN                          NaN
# 1                      NaN                 NaN                          NaN
# 2                      NaN                 NaN                          NaN
# 3                      NaN                 NaN                          NaN
# 4                      NaN                 NaN                          NaN
# 5                      NaN                 NaN                          NaN
# 6                      NaN                 NaN                          NaN
# 7                      NaN                 NaN                          NaN
# 8                      NaN                 NaN                          NaN
# 9                      NaN                 NaN                          NaN
# 10                     NaN                 NaN                          NaN
# 11                     NaN                 NaN                          NaN
# 12                     NaN                 NaN                          NaN
# 13                     NaN                 NaN                          NaN
# 14                     NaN                 NaN                          NaN
# 15                     NaN                 NaN                          NaN
# 16                     NaN                 NaN                          NaN
# 17                     NaN                 NaN                          NaN
# 18                     NaN                 NaN                          NaN
# 19                     NaN                 NaN                          NaN
# 20                     NaN                 NaN                          NaN
# 21                     NaN                 NaN                          NaN
# 22                     NaN                 NaN                          NaN
# 23                     NaN                 NaN                          NaN
# 24                     NaN                 NaN                          NaN
# 25                     NaN                 NaN                          NaN
# 26                     NaN                 NaN                          NaN
# 27                     NaN                 NaN                          NaN
# 28                     NaN                 NaN                          NaN
# 29                     NaN                 NaN                          NaN
# 30                     NaN                 NaN                          NaN
# 31                     NaN                 NaN                          NaN
# 32                    true                Pipe  fraud-detection-11-04-46-52
#
#     label_col max_dataset_size max_subsampled_dataset_size  \
# 0         NaN              NaN                         NaN
# 1         NaN              NaN                         NaN
# 2         NaN              NaN                         NaN
# 3         NaN              NaN                         NaN
# 4         NaN              NaN                         NaN
# 5         NaN              NaN                         NaN
# 6         NaN              NaN                         NaN
# 7         NaN              NaN                         NaN
# 8         NaN              NaN                         NaN
# 9         NaN              NaN                         NaN
# 10        NaN              NaN                         NaN
# 11        NaN              NaN                         NaN
# 12        NaN              NaN                         NaN
# 13        NaN              NaN                         NaN
# 14        NaN              NaN                         NaN
# 15        NaN              NaN                         NaN
# 16        NaN              NaN                         NaN
# 17        NaN              NaN                         NaN
# 18        NaN              NaN                         NaN
# 19        NaN              NaN                         NaN
# 20        NaN              NaN                         NaN
# 21        NaN              NaN                         NaN
# 22        NaN              NaN                         NaN
# 23        NaN              NaN                         NaN
# 24        NaN              NaN                         NaN
# 25        NaN              NaN                         NaN
# 26        NaN              NaN                         NaN
# 27        NaN              NaN                         NaN
# 28        NaN              NaN                         NaN
# 29        NaN              NaN                         NaN
# 30        NaN              NaN                         NaN
# 31        NaN              NaN                         NaN
# 32      Class              100                           5
#
#     SageMaker.ImageUri - MediaType  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
#
#                            SageMaker.ImageUri - Value  ds - MediaType  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
# 15                                                NaN             NaN
# 16                                                NaN             NaN
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19                                                NaN             NaN
# 20                                                NaN             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                                                NaN             NaN
# 26                                                NaN             NaN
# 27                                                NaN             NaN
# 28                                                NaN             NaN
# 29                                                NaN             NaN
# 30                                                NaN             NaN
# 31                                                NaN             NaN
# 32  550855508252.dkr.ecr.eu-central-1.amazonaws.co...             NaN
#
#                                            ds - Value
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  s3://sagemaker-eu-central-1-705561729853/sagem...
#
# [33 rows x 234 columns]

# %% [markdown]
# ## Listing all candidates explored by Amazon SageMaker AutoPilot
# Once the 'ModelTuning' step is complete, we can list top candidates that were identified by SageMaker AutoPilot, and sort them by their final performance metric.

# %%
candidates = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name, 
                                                SortBy='FinalObjectiveMetricValue')['Candidates']
index = 1
for candidate in candidates:
  print (str(index) + "  " 
         + candidate['CandidateName'] + "  " 
         + str(candidate['FinalAutoMLJobObjectiveMetric']['Value']))
  index += 1
# Out:
# 1  fraud-detection-11-04-46-52EtgHM-011-218f95f5  0.8444399833679199
# 2  fraud-detection-11-04-46-52EtgHM-015-ef5ac858  0.8351699709892273
# 3  fraud-detection-11-04-46-52EtgHM-004-0aeeed95  0.6523600220680237
# 4  fraud-detection-11-04-46-52EtgHM-019-09a41b6d  0.644070029258728
# 5  fraud-detection-11-04-46-52EtgHM-014-2eb92b33  0.6104400157928467
# 6  fraud-detection-11-04-46-52EtgHM-005-8200efaa  0.485289990901947
# 7  fraud-detection-11-04-46-52EtgHM-008-c5fbd4ef  0.30254998803138733
# 8  fraud-detection-11-04-46-52EtgHM-009-f9c2449d  0.3001900017261505
# 9  fraud-detection-11-04-46-52EtgHM-007-526ae705  0.20699000358581543
# 10  fraud-detection-11-04-46-52EtgHM-006-59b99a28  0.20051999390125275

# %%
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['BestCandidate']
best_candidate_name = best_candidate['CandidateName']

print("Candidate name: " + best_candidate_name)
# Out:
# Candidate name: fraud-detection-11-04-46-52EtgHM-011-218f95f5

# %% [markdown]
# ## Evaluate on Testset by Hosting an Endpoint
# Let's now deploy the model as endpoint and then make predictions on the test set to see how well the model performs on the hold-out test set.

# %%
timestamp_suffix = strftime("%d-%H-%M-%S", gmtime())
model_name = best_candidate_name + timestamp_suffix + "-model"
model_arn = sm.create_model(
    Containers=best_candidate["InferenceContainers"], ModelName=model_name, ExecutionRoleArn=role
)

epc_name = best_candidate_name + timestamp_suffix + "-epc"
ep_config = sm.create_endpoint_config(
    EndpointConfigName=epc_name,
    ProductionVariants=[
        {
            "InstanceType": "ml.m5.2xlarge",
            "InitialInstanceCount": 1,
            "ModelName": model_name,
            "VariantName": "main",
        }
    ],
)

ep_name = best_candidate_name + timestamp_suffix + "-ep"
create_endpoint_response = sm.create_endpoint(EndpointName=ep_name, EndpointConfigName=epc_name)

# %%
sm.get_waiter("endpoint_in_service").wait(EndpointName=ep_name)

# %% [markdown]
# ### Evaluate

# %%
tp = tn = fp = fn = count = 0

with open('automl-test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:   # Skip header
        l = l.split(',')  # Split CSV line into features
        label = l[-1]     # Store 0/1 label
        l = l[:-1]        # Remove label
        l = ','.join(l)   # Rebuild CSV line without label
                
        response = sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=l)

        response = response['Body'].read().decode("utf-8")
        #print ("label %s response %s" %(label,response))

        if '1' in label:
            # Sample is positive
            if '1' in response:
                # True positive
                tp=tp+1
            else:
                # False negative
                fn=fn+1
        else:
            # Sample is negative
            if '0' in response:
                # True negative
                tn=tn+1
            else:
                # False positive
                fp=fp+1
        count = count+1
        if (count % 100 == 0):   
            sys.stdout.write(str(count)+' ')
            
print ("Done")
# Out:
# 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400 8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700 9800 9900 10000 10100 10200 10300 10400 10500 10600 10700 10800 10900 11000 11100 11200 11300 11400 11500 11600 11700 11800 11900 12000 12100 12200 12300 12400 12500 12600 12700 12800 12900 13000 13100 13200 13300 13400 13500 13600 13700 13800 13900 14000 14100 14200 14300 14400 14500 14600 14700 14800 14900 15000 15100 15200 15300 15400 15500 15600 15700 15800 15900 16000 16100 16200 16300 16400 16500 16600 16700 16800 16900 17000 17100 17200 17300 17400 17500 17600 17700 17800 17900 18000 18100 18200 18300 18400 18500 18600 18700 18800 18900 19000 19100 19200 19300 19400 19500 19600 19700 19800 19900 20000 20100 20200 20300 20400 20500 20600 20700 20800 20900 21000 21100 21200 21300 21400 21500 21600 21700 21800 21900 22000 22100 22200 22300 22400 22500 22600 22700 22800 22900 23000 23100 23200 23300 23400 23500 23600 23700 23800 23900 24000 24100 24200 24300 24400 24500 24600 24700 24800 24900 25000 25100 25200 25300 25400 25500 25600 25700 25800 25900 26000 26100 26200 26300 26400 26500 26600 26700 26800 26900 27000 27100 27200 27300 27400 27500 27600 27700 27800 27900 28000 28100 28200 28300 28400 28500 28600 28700 28800 28900 29000 29100 29200 29300 29400 29500 29600 29700 29800 29900 30000 30100 30200 30300 30400 30500 30600 30700 30800 30900 31000 31100 31200 31300 31400 31500 31600 31700 31800 31900 32000 32100 32200 32300 32400 32500 32600 32700 32800 32900 33000 33100 33200 33300 33400 33500 33600 33700 33800 33900 34000 34100 34200 34300 34400 34500 34600 34700 34800 34900 35000 35100 35200 35300 35400 35500 35600 35700 35800 35900 36000 36100 36200 36300 36400 36500 36600 36700 36800 36900 37000 37100 37200 37300 37400 37500 37600 37700 37800 37900 38000 38100 38200 38300 38400 38500 38600 38700 38800 38900 39000 39100 39200 39300 39400 39500 39600 39700 39800 39900 40000 40100 40200 40300 40400 40500 40600 40700 40800 40900 41000 41100 41200 41300 41400 41500 41600 41700 41800 41900 42000 42100 42200 42300 42400 42500 42600 42700 42800 42900 43000 43100 43200 43300 43400 43500 43600 43700 43800 43900 44000 44100 44200 44300 44400 44500 44600 44700 44800 44900 45000 45100 45200 45300 45400 45500 45600 45700 45800 45900 46000 46100 46200 46300 46400 46500 46600 46700 46800 46900 47000 47100 47200 47300 47400 47500 47600 47700 47800 47900 48000 48100 48200 48300 48400 48500 48600 48700 48800 48900 49000 49100 49200 49300 49400 49500 49600 49700 49800 49900 50000 50100 50200 50300 50400 50500 50600 50700 50800 50900 51000 51100 51200 51300 51400 51500 51600 51700 51800 51900 52000 52100 52200 52300 52400 52500 52600 52700 52800 52900 53000 53100 53200 53300 53400 53500 53600 53700 53800 53900 54000 54100 54200 54300 54400 54500 54600 54700 54800 54900 55000 55100 55200 55300 55400 55500 55600 55700 55800 55900 56000 56100 56200 56300 56400 56500 56600 56700 56800 56900 Done

# %%
 # Confusion matrix
print ("%d %d" % (tn, fp))
print ("%d %d" % (fn, tp))

accuracy  = (tp+tn)/(tp+tn+fp+fn)
precision = tp/(tp+fp)
recall    = tp/(tp+fn)
f1        = (2*precision*recall)/(precision+recall)

print ("Accuracy: %.4f, Precision: %.4f, Recall: %.4f, F1: %.4f" % (accuracy, precision, recall, f1))
# Out:
# 56830 7
# 3 121
# Accuracy: 0.9998, Precision: 0.9453, Recall: 0.9758, F1: 0.9603
